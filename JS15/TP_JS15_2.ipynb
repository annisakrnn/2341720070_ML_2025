# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf8bf91f-5366-45c7-b4bc-96b9e5d5d60d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf8bf91f-5366-45c7-b4bc-96b9e5d5d60d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score

# Load dataset
df = pd.read_csv('/content/spam (1).csv', encoding='latin-1')

# Ambil kolom yang diperlukan
df = df[['v1','v2']]
df.columns = ['label','text']

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['label'], test_size=0.2, random_state=42
)

# 1. Multinomial Naive Bayes + CountVectorizer
cv = CountVectorizer(stop_words='english')
X_train_cv = cv.fit_transform(X_train)
X_test_cv = cv.transform(X_test)

model_cv = MultinomialNB()
model_cv.fit(X_train_cv, y_train)
pred_cv = model_cv.predict(X_test_cv)

print("=== CountVectorizer Result ===")
print("Accuracy:", accuracy_score(y_test, pred_cv))
print(classification_report(y_test, pred_cv))

# 2. Multinomial Naive Bayes + TF-IDF
tfidf = TfidfVectorizer(stop_words='english')
X_train_tf = tfidf.fit_transform(X_train)
X_test_tf = tfidf.transform(X_test)

model_tf = MultinomialNB()
model_tf.fit(X_train_tf, y_train)
pred_tf = model_tf.predict(X_test_tf)

print("=== TF-IDF Result ===")
print("Accuracy:", accuracy_score(y_test, pred_tf))
print(classification_report(y_test, pred_tf))
# Out:
# === CountVectorizer Result ===
# Accuracy: 0.9838565022421525
#               precision    recall  f1-score   support
#
#          ham       0.99      0.99      0.99       965
#         spam       0.96      0.92      0.94       150
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.96      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
#
# === TF-IDF Result ===
# Accuracy: 0.9668161434977578
#               precision    recall  f1-score   support
#
#          ham       0.96      1.00      0.98       965
#         spam       1.00      0.75      0.86       150
#
#     accuracy                           0.97      1115
#    macro avg       0.98      0.88      0.92      1115
# weighted avg       0.97      0.97      0.96      1115

# %% [markdown]
# Hasilnya:
#
# Model CountVectorizer mampu menangkap kata-kata yang sering muncul pada pesan spam sehingga menghasilkan performa akurasi sangat baik sebesar 98,39%. Model ini memiliki kelebihan dapat mempertahankan frekuensi kata yang sering muncul dan cocok untuk deteksi spam selain itu model Naive Bayes juga sesuai dengan data yang berbasis jumlah data.
#
# Perbandingan dengan TF-IDF menunjukkan bahwa TF-IDF bekerja baik namun akurasinya lebih rendah daripada CountVectorizer yaitu sejumlah 96,68&
#
# Kesimpulanya fitur yang terbaik adalah 'english'
